# %% [markdown]
# # Cats and Dogs

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import cv2
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from sklearn.model_selection import train_test_split

rows = 128
cols= 128

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import os, shutil
# print(os.listdir("../input"))

# %%
source_data_dir = "data/train"
try:
    os.mkdir("data/training_set/cats")
    os.mkdir("data/training_set/dogs")
    os.mkdir("data/validation_set/cats")
    os.mkdir("data/validation_set/dogs")
except:
    pass

# %%
if os.listdir("data/training_set/cats")=="":
    # If the folder contains no pictures start copying
    for file in ["cat.{}.jpg".format(i) for i in range (2000)]:
        shutil.copyfile(os.path.join(source_data_dir, file), os.path.join("data/training_set/cats", file))
    for file in ["dog.{}.jpg".format(i) for i in range (2000)]:
        shutil.copyfile(os.path.join(source_data_dir, file), os.path.join("data/training_set/dogs", file))
    for file in ["cat.{}.jpg".format(i) for i in range (2000, 2500)]:
        shutil.copyfile(os.path.join(source_data_dir, file), os.path.join("data/validation_set/cats", file))
    for file in ["dog.{}.jpg".format(i) for i in range (2000, 2500)]:
        shutil.copyfile(os.path.join(source_data_dir, file), os.path.join("data/validation_set/dogs", file))

# %% [markdown]
# # Data Pre-processing

# %%
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras import models

model = models.Sequential()
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(rows, cols, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# d:\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12544)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               6423040
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 6,479,873
# Trainable params: 6,479,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import optimizers
model.compile(loss='binary_crossentropy',
              optimizer=optimizers.rmsprop(lr=1e-4),
              metrics=['acc'])

# %%
from keras.preprocessing.image import ImageDataGenerator

x_train_datagen = ImageDataGenerator(rescale=1./255)
x_val_datagen = ImageDataGenerator(rescale=1./255)

train_datagen = x_train_datagen.flow_from_directory("data/training_set",
                                                    target_size=(rows,cols),
                                                    batch_size=40,
                                                    class_mode='binary')
val_datagen = x_val_datagen.flow_from_directory("data/validation_set",
                                                target_size=(rows,cols),
                                                batch_size=40,
                                                class_mode='binary')
# Out:
# Found 4000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %%
epochs = 30

# steps_per_epoch = samples / batch_size

H = model.fit_generator(train_datagen,
                        steps_per_epoch=100, 
                        epochs=epochs,
                        validation_data=val_datagen,
                        validation_steps=50)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 72s 722ms/step - loss: 0.7024 - acc: 0.5755 - val_loss: 0.6248 - val_acc: 0.6350
# Epoch 2/30
# 100/100 [==============================] - 12s 117ms/step - loss: 0.6115 - acc: 0.6660 - val_loss: 0.5746 - val_acc: 0.6890
# Epoch 3/30
# 100/100 [==============================] - 12s 115ms/step - loss: 0.5604 - acc: 0.7112 - val_loss: 0.5629 - val_acc: 0.7250
# Epoch 4/30
# 100/100 [==============================] - 11s 112ms/step - loss: 0.5218 - acc: 0.7425 - val_loss: 0.5405 - val_acc: 0.7310
# Epoch 5/30
# 100/100 [==============================] - 11s 112ms/step - loss: 0.4949 - acc: 0.7605 - val_loss: 0.5103 - val_acc: 0.7460
# Epoch 6/30
# 100/100 [==============================] - 11s 111ms/step - loss: 0.4653 - acc: 0.7790 - val_loss: 0.5357 - val_acc: 0.7390
# Epoch 7/30
# 100/100 [==============================] - 11s 115ms/step - loss: 0.4340 - acc: 0.8023 - val_loss: 0.5043 - val_acc: 0.7490
# Epoch 8/30
# 100/100 [==============================] - 12s 120ms/step - loss: 0.4117 - acc: 0.8155 - val_loss: 0.5112 - val_acc: 0.7540
# Epoch 9/30
# 100/100 [==============================] - 12s 118ms/step - loss: 0.3810 - acc: 0.8347 - val_loss: 0.4939 - val_acc: 0.7730
# Epoch 10/30
# 100/100 [==============================] - 12s 120ms/step - loss: 0.3597 - acc: 0.8423 - val_loss: 0.5160 - val_acc: 0.7540
# Epoch 11/30
# 100/100 [==============================] - 12s 119ms/step - loss: 0.3324 - acc: 0.8605 - val_loss: 0.5225 - val_acc: 0.7600
# Epoch 12/30
# 100/100 [==============================] - 11s 115ms/step - loss: 0.3092 - acc: 0.8753 - val_loss: 0.5340 - val_acc: 0.7460
# Epoch 13/30
# 100/100 [==============================] - 11s 113ms/step - loss: 0.2868 - acc: 0.8798 - val_loss: 0.5205 - val_acc: 0.7700
# Epoch 14/30
# 100/100 [==============================] - 11s 113ms/step - loss: 0.2637 - acc: 0.8967 - val_loss: 0.5738 - val_acc: 0.7580
# Epoch 15/30
# 100/100 [==============================] - 11s 109ms/step - loss: 0.2461 - acc: 0.9045 - val_loss: 0.5354 - val_acc: 0.7690
# Epoch 16/30
# 100/100 [==============================] - 11s 111ms/step - loss: 0.2247 - acc: 0.9128 - val_loss: 0.5888 - val_acc: 0.7490
# Epoch 17/30
# 100/100 [==============================] - 11s 113ms/step - loss: 0.2104 - acc: 0.9230 - val_loss: 0.7268 - val_acc: 0.7130
# Epoch 18/30
# 100/100 [==============================] - 11s 111ms/step - loss: 0.1855 - acc: 0.9318 - val_loss: 0.6034 - val_acc: 0.7540
# Epoch 19/30
# 100/100 [==============================] - 11s 111ms/step - loss: 0.1657 - acc: 0.9412 - val_loss: 0.6120 - val_acc: 0.7770
# Epoch 20/30
# 100/100 [==============================] - 11s 113ms/step - loss: 0.1546 - acc: 0.9455 - val_loss: 0.6310 - val_acc: 0.7640
# Epoch 21/30
# 100/100 [==============================] - 11s 114ms/step - loss: 0.1362 - acc: 0.9535 - val_loss: 0.8441 - val_acc: 0.7040
# Epoch 22/30
# 100/100 [==============================] - 11s 111ms/step - loss: 0.1191 - acc: 0.9610 - val_loss: 0.6868 - val_acc: 0.7630
# Epoch 23/30
# 100/100 [==============================] - 11s 112ms/step - loss: 0.1089 - acc: 0.9665 - val_loss: 0.7123 - val_acc: 0.7650
# Epoch 24/30
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0942 - acc: 0.9690 - val_loss: 0.7829 - val_acc: 0.7490
# Epoch 25/30
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0824 - acc: 0.9748 - val_loss: 0.7679 - val_acc: 0.7540
# Epoch 26/30
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0719 - acc: 0.9838 - val_loss: 0.8196 - val_acc: 0.7560
# Epoch 27/30
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0637 - acc: 0.9845 - val_loss: 0.8477 - val_acc: 0.7570
# Epoch 28/30
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0587 - acc: 0.9828 - val_loss: 0.8732 - val_acc: 0.7490
# Epoch 29/30
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0502 - acc: 0.9868 - val_loss: 0.9246 - val_acc: 0.7470
# Epoch 30/30
# 100/100 [==============================] - 12s 117ms/step - loss: 0.0428 - acc: 0.9890 - val_loss: 0.9400 - val_acc: 0.7500

# %%
acc = H.history['acc']
val_acc = H.history['val_acc']
loss = H.history['loss']
val_loss = H.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'g', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# Previous Architecture

# %%
acc = H.history['acc']
val_acc = H.history['val_acc']
loss = H.history['loss']
val_loss = H.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'g', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'g', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
model.save('cats_and_dogs.h5')  # creates a HDF5 file

# %% [markdown]
# References:
#
# 1. [Anthony Tanbakuchi](http://tanbakuchi.com/posts/comparison-of-openv-interpolation-algorithms/ )

# %% [markdown]
# https://elitedatascience.com/keras-tutorial-deep-learning-in-python
#
# https://keras.io/applications/
